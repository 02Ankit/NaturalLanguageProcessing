# %%
# !pip install gensim
# Out:
# ...
#   Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB 9.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.7/24.0 MB 8.6 MB/s eta 0:00:03
#    - -------------------------------------- 1.2/24.0 MB 9.2 MB/s eta 0:00:03
#    -- ------------------------------------- 1.4/24.0 MB 8.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.8/24.0 MB 7.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.6/24.0 MB 7.5 MB/s eta 0:00:03
#    ------ --------------------------------- 4.1/24.0 MB 7.3 MB/s eta 0:00:03
#    ------- -------------------------------- 4.7/24.0 MB 7.2 MB/s eta 0:00:03
#    -------- ------------------------------- 5.2/24.0 MB 7.3 MB/s eta 0:00:03
#    --------- ------------------------------ 5.5/24.0 MB 7.1 MB/s eta 0:00:03
# ...

# %% [markdown]
# #### When we haveve huge data set we use to SkipGram otherwise use CBOW

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
## we use the pretrained model 
## google has created  this pretrained model word2vec-google-news-300
wv = api.load('word2vec-google-news-300')
## Google news text data which have more then 300 billion words
## 300 means -> 300 dimensions an output
vec_king = wv['King']

# %%
vec_king
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 vec_king
#
# NameError: name 'vec_king' is not defined

# %%
wv['man']

# %%
wv.most_similar('man') ## Cosine Similarity angle between the vector we have to calculate

# %%
wv.most_similar('cricket')

# %%
wv.most_similar('man', 'king')

# %%
 wv.most_similar('happy')

# %%
##Check Similarity between tw words
wv.similarity('cricket', 'sports')# yes cricket is a sport its similarity

# %%
wv.similarity('hockey', 'sports')

# %%
vec = wv['king']-wv['man']+wv['woman']

# %%
vec

# %%
wv.most_similar([vec])
